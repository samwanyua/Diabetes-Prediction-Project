# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Data collection and analysis - PIMA Diabetes Dataset

# %%
diabetes_dataset = pd.read_csv('../Dataset/diabetes.csv')
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
# check the number of rows and columns
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
# statistical measures of the data
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
#  0 -> Non diabetic
#  1 -> Diabetic

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  ...  DiabetesPedigreeFunction        Age
# Outcome                           ...
# 0           3.298000  109.980000  ...                  0.429734  31.190000
# 1           4.865672  141.257463  ...                  0.550500  37.067164
#
# [2 rows x 8 columns]

# %%
# Outcome distribution
sns.countplot(x='Outcome', data=diabetes_dataset)
plt.title('Distribution of Diabetes Outcome')
plt.xticks([0,1], ['No Diabetes', 'Diabetes'])
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.show()

# %%
# correlation heatmap
plt.figure(figsize=(10,8))
sns.heatmap(diabetes_dataset.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature correlation heatmap')
plt.show()

# %%
# compare feature distribution by outcome
features = ['Glucose', 'BMI', 'Age', 'Insulin', 'BloodPressure']
for col in features:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='Outcome', y=col, data = diabetes_dataset)
    plt.title(f'{col} by Outcome')
    plt.xticks([0,1], ['No Diabetes', 'Diabetes'])
    plt.show()

# %%
sns.pairplot(diabetes_dataset, hue='Outcome', vars=['Glucose', 'BMI', 'Age', 'Insulin'])
plt.suptitle('Pairwise Plots of Selected Features', y=1.02)
plt.show()

# %%
# Age distributions
plt.figure(figsize=(8, 4))
sns.histplot(data=diabetes_dataset, x='Age', hue='Outcome', bins=20, kde=True, palette='pastel')
plt.title('Age Distribution by Diabetes Outcome')
plt.show()

# %%
# BMI vs Glucose 
plt.figure(figsize=(6, 4))
sns.scatterplot(data=diabetes_dataset, x='BMI', y='Glucose', hue='Outcome', palette='Set1')
plt.title('BMI vs Glucose by Diabetes Outcome')
plt.show()

# %%
# zero-value checks
zero_cols = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
diabetes_dataset[zero_cols].isin([0]).sum().plot(kind='bar', title='Count of Zero Values in Each Feature')
plt.ylabel('Number of Zero Values')
plt.show()

# %%
# Separate data and labels
X = diabetes_dataset.drop(columns='Outcome', axis=1)
y = diabetes_dataset['Outcome']
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# ...

# %%
print(y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
# Train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %%
# Train the model
classifier = svm.SVC(kernel='linear')
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# model evaluation
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)
print('Accuracy score of the training data: ', training_data_accuracy)
# Out:
# Accuracy score of the training data:  0.7833876221498371
